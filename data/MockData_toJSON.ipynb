# %%
import csv
import numpy as np
import pandas as pd
import json
from functools import reduce

# %%
# data = pd.read_csv("TestData/MockData2-goodNames-normalized.csv") 
# data = pd.read_csv("TestData/COVID.csv")
data = pd.read_csv("TestData/1_ToyDataset-All.csv")

# %%
data
# Out:
#          State SourceID  SourceNodeColor  SourceNodeSize  EdgeColor  \
# 0   TimeStamp0  Source1           -0.820           1.200     -1.800
# 1   TimeStamp0  Source1           -0.820           1.200     -1.800
# 2   TimeStamp0  Source1           -0.820           1.200     -1.800
# 3   TimeStamp0  Source1           -0.820           1.200     -1.800
# 4   TimeStamp0  Source1           -0.820           1.200     -0.140
# 5   TimeStamp0  Source1           -0.820           1.200      2.946
# 6   TimeStamp0  Source1           -0.820           1.200      2.946
# 7   TimeStamp0  Source1           -0.820           1.200      2.946
# 8   TimeStamp0  Source1           -0.820           1.200      2.946
# 9   TimeStamp0  Source1           -0.820           1.200      2.480
# 10  TimeStamp0  Source1           -0.820           1.200      0.500
# 11  TimeStamp0  Source1           -0.820           1.200     -2.950
# 12  TimeStamp0  Source2            3.730           2.345     -2.210
# 13  TimeStamp0  Source2            3.730           2.345     -2.210
# 14  TimeStamp0  Source2            3.730           2.345     -2.210
# 15  TimeStamp0  Source2            3.730           2.345     -2.210
# 16  TimeStamp0  Source2            3.730           2.345     -3.560
# 17  TimeStamp0  Source3            2.340           1.510      1.950
# 18  TimeStamp0  Source3            2.340           1.510      0.060
# 19  TimeStamp0  Source3            2.340           1.510      0.060
# 20  TimeStamp0  Source3            2.340           1.510      0.060
# 21  TimeStamp0  Source3            2.340           1.510      0.060
# 22  TimeStamp0  Source3            2.340           1.510     -2.910
# 23  TimeStamp0  Source3            2.340           1.510     -2.910
# 24  TimeStamp0  Source3            2.340           1.510     -2.290
# 25  TimeStamp0  Source3            2.340           1.510      0.930
# 26  TimeStamp0  Source3            2.340           1.510      2.960
# 27  TimeStamp0  Source3            2.340           1.510     -1.600
# 28  TimeStamp0  Source3            2.340           1.510     -3.510
# 29  TimeStamp0  Source3            2.340           1.510      1.790
# 30  TimeStamp0  Source3            2.340           1.510     -3.800
# 31  TimeStamp0  Source4           -1.600           1.780     -0.930
# 32  TimeStamp0  Source4           -1.600           1.780     -0.930
# 33  TimeStamp0  Source4           -1.600           1.780     -0.930
# 34  TimeStamp0  Source4           -1.600           1.780     -0.930
# 35  TimeStamp0  Source4           -1.600           1.780     -0.930
# 36  TimeStamp0  Source4           -1.600           1.780     -0.930
# 37  TimeStamp0  Source4           -1.600           1.780      2.480
# 38  TimeStamp0  Source4           -1.600           1.780      1.660
# 39  TimeStamp0  Source4           -1.600           1.780     -0.670
# 40  TimeStamp0  Source4           -1.600           1.780     -2.330
# 41  TimeStamp0  Source5            2.371           3.470      1.980
# 42  TimeStamp0  Source5            2.371           3.470      1.980
# 43  TimeStamp0  Source5            2.371           3.470      1.980
# 44  TimeStamp0  Source5            2.371           3.470      1.980
# 45  TimeStamp0  Source5            2.371           3.470      1.980
# 46  TimeStamp0  Source5            2.371           3.470      1.980
# 47  TimeStamp0  Source5            2.371           3.470      2.400
# 48  TimeStamp0  Source5            2.371           3.470      2.400
# 49  TimeStamp0  Source5            2.371           3.470      2.400
# 50  TimeStamp0  Source5            2.371           3.470      2.400
# 51  TimeStamp0  Source5            2.371           3.470      2.400
# 52  TimeStamp0  Source5            2.371           3.470      2.400
# 53  TimeStamp0  Source5            2.371           3.470      0.320
# 54  TimeStamp0  Source6            2.880           2.090      0.960
# 55  TimeStamp0  Source6            2.880           2.090      0.960
# 56  TimeStamp0  Source6            2.880           2.090      3.210
# 57  TimeStamp0  Source6            2.880           2.090      3.210
# 58  TimeStamp0  Source6            2.880           2.090      3.360
#
#     EdgeWeight  TargetID  TargetNodeSize PhosphorylationSiteID  \
# 0         3.38   Target1            1.16         SiteTarget1-1
# 1         3.38   Target1            1.16         SiteTarget1-2
# 2         3.38   Target1            1.16         SiteTarget1-3
# 3         3.38   Target1            1.16         SiteTarget1-4
# 4         0.60   Target2            0.77         SiteTarget2-1
# 5         0.55   Target3            2.31         SiteTarget3-1
# 6         0.55   Target3            2.31         SiteTarget3-2
# 7         0.55   Target3            2.31         SiteTarget3-3
# 8         0.55   Target3            2.31         SiteTarget3-4
# 9         3.14   Target4            2.12         SiteTarget4-1
# 10        0.80   Target5            2.14         SiteTarget5-1
# 11        1.42   Target6            3.11         SiteTarget6-1
# 12        1.04   Target1            1.16         SiteTarget1-1
# 13        1.04   Target1            1.16         SiteTarget1-2
# 14        1.04   Target1            1.16         SiteTarget1-3
# 15        1.04   Target1            1.16         SiteTarget1-4
# 16        1.34   Target7            2.97         SiteTarget7-1
# 17        0.84   Target8            1.03         SiteTarget8-1
# 18        2.50   Target3            2.31         SiteTarget3-1
# 19        2.50   Target3            2.31         SiteTarget3-2
# 20        2.50   Target3            2.31         SiteTarget3-3
# 21        2.50   Target3            2.31         SiteTarget3-4
# 22        3.36   Target9            1.17         SiteTarget9-1
# 23        3.36   Target9            1.17         SiteTarget9-2
# 24        2.16  Target10            3.58        SiteTarget10-1
# 25        1.24  Target11            1.03        SiteTarget11-1
# 26        2.07  Target12            2.72        SiteTarget12-1
# 27        3.51  Target13            0.14        SiteTarget13-1
# 28        3.73  Target14            3.09        SiteTarget14-1
# 29        2.51  Target15            2.23        SiteTarget15-1
# 30        2.07  Target16            2.28        SiteTarget16-1
# 31        3.26  Target17            3.70        SiteTarget17-1
# 32        3.26  Target17            3.70        SiteTarget17-2
# 33        3.26  Target17            3.70        SiteTarget17-3
# 34        3.26  Target17            3.70        SiteTarget17-4
# 35        3.26  Target17            3.70        SiteTarget17-5
# 36        3.26  Target17            3.70        SiteTarget17-6
# 37        2.46  Target18            3.89        SiteTarget18-1
# 38        1.45  Target18            3.55        SiteTarget18-2
# 39        0.01  Target19            0.80        SiteTarget19-1
# 40        1.93  Target20            2.68        SiteTarget20-1
# 41        2.09  Target21            0.73        SiteTarget21-1
# 42        2.09  Target21            0.73        SiteTarget21-2
# 43        2.09  Target21            0.73        SiteTarget21-3
# 44        2.09  Target21            0.73        SiteTarget21-4
# 45        2.09  Target22            0.73        SiteTarget22-1
# 46        2.09  Target23            0.73        SiteTarget23-1
# 47        3.84  Target17            3.70        SiteTarget17-1
# 48        3.84  Target17            3.70        SiteTarget17-2
# 49        3.84  Target17            3.70        SiteTarget17-3
# 50        3.84  Target17            3.70        SiteTarget17-4
# 51        3.84  Target17            3.70        SiteTarget17-5
# 52        3.84  Target17            3.70        SiteTarget17-6
# 53        2.71   Target5            2.14         SiteTarget5-1
# 54        2.04  Target24            0.01        SiteTarget24-2
# 55        2.04  Target24            0.01        SiteTarget24-3
# 56        1.84  Target25            1.70        SiteTarget25-1
# 57        1.84  Target26            1.70        SiteTarget26-1
# 58        3.42  Target23            3.66        SiteTarget23-1
#
#     TargetNodeColor
# 0             -1.76
# 1              0.88
# 2              0.67
# 3             -0.71
# 4             -1.35
# 5              3.31
# 6             -1.72
# 7             -1.18
# 8             -2.72
# 9              3.28
# 10            -2.52
# 11             2.72
# 12            -3.41
# 13             0.39
# 14            -0.34
# 15             3.13
# 16             2.20
# 17             1.10
# 18             2.80
# 19             2.02
# 20            -3.75
# 21            -1.79
# 22            -1.97
# 23             1.74
# 24            -0.93
# 25            -1.53
# 26            -1.53
# 27             1.21
# 28            -2.68
# 29             3.34
# 30            -3.26
# 31            -0.46
# 32             1.35
# 33            -3.58
# 34            -0.67
# 35            -0.38
# 36             3.38
# 37            -2.09
# 38             2.28
# 39            -2.57
# 40            -3.82
# 41            -2.98
# 42             2.73
# 43            -1.07
# 44             0.95
# 45            -1.21
# 46            -1.09
# 47            -2.56
# 48             2.60
# 49            -3.37
# 50            -3.70
# 51            -2.48
# 52             1.47
# 53            -0.89
# 54             3.89
# 55            -1.75
# 56            -2.40
# 57            -3.34
# 58            -3.57

# %%
def normalize(values, actual_bounds, desired_bounds):
    final = []
    for i in values:
        final.append(desired_bounds[0] + (i - actual_bounds[0]) * (desired_bounds[1] - desired_bounds[0]) / (actual_bounds[1] - actual_bounds[0]))
    return final

# %%
def attribute_dict (dataframe, col_name_source_or_target, col_name_attribute_of_interest):
    dictionary = {}
    
    min_val = min(dataframe[col_name_attribute_of_interest].values)
    max_val = max(dataframe[col_name_attribute_of_interest].values)
    actual_bounds = (min_val, max_val)
    desired_bounds = (0, 1)
    
    for i in range(len(dataframe)):
        if col_name_attribute_of_interest in dataframe.columns:
            value = dataframe[col_name_attribute_of_interest][i]
            dictionary[dataframe[col_name_source_or_target][i]] = normalize([value], actual_bounds, desired_bounds)[0]
        else:
            dictionary[dataframe[col_name_source_or_target][i]] = None
            
    return dictionary

# %%
source_att_1 = attribute_dict(data, "SourceID", "SourceNodeColor")
source_att_1
# Out:
# {'Source1': 0.14634146341463417,
#  'Source2': 1.0,
#  'Source3': 0.7392120075046904,
#  'Source4': 0.0,
#  'Source5': 0.7450281425891182,
#  'Source6': 0.8405253283302064}

# %%
def partitions_dict (dataframe, col_name_target, col_name_partitions, col_name_attribute_of_interest):
    partitions = {}
    rep = {}

    target = dataframe[col_name_target]
    val = dataframe[col_name_attribute_of_interest]

    if col_name_partitions in dataframe.columns:
        site = dataframe[col_name_partitions]
        for i in range(len(dataframe)):
            if target[i] not in partitions:
                partitions[target[i]] = [{site[i]: val[i]}]
                rep[target[i]] = [site[i]]

            else:
                if site[i] not in rep[target[i]]:
                    partitions[target[i]] += [{site[i]: val[i]}]
                    rep[target[i]] += [site[i]]
    
    return partitions

# %%
def links_info (dataframe, col_name_source, col_name_target):
    links = []

    for i in range(len(data)):
        if [dataframe[col_name_source][i], dataframe[col_name_target][i]] not in links:
            links.append([dataframe[col_name_source][i], dataframe[col_name_target][i]])
    return links

# %%
source_att_1 = attribute_dict(data, "SourceID", "SourceNodeColor")
source_att_2 = attribute_dict(data, "SourceID", "SourceNodeSize")
target_att_1 = attribute_dict(data, "TargetID", "TargetNodeColor")
target_att_2 = attribute_dict(data, "TargetID", "TargetNodeSize")
edge_att_1 = attribute_dict(data, "TargetID", "EdgeColor")
edge_att_2 = attribute_dict(data, "TargetID", "EdgeWeight")

partitions = partitions_dict(data, "TargetID", "PhosphorylationSiteID", "TargetNodeColor")
links = links_info(data, "SourceID", "TargetID")

# %%
partitions
# Out:
# {'Target1': [{'SiteTarget1-1': -1.76},
#   {'SiteTarget1-2': 0.88},
#   {'SiteTarget1-3': 0.67},
#   {'SiteTarget1-4': -0.71}],
#  'Target2': [{'SiteTarget2-1': -1.35}],
#  'Target3': [{'SiteTarget3-1': 3.31},
#   {'SiteTarget3-2': -1.72},
#   {'SiteTarget3-3': -1.18},
#   {'SiteTarget3-4': -2.72}],
#  'Target4': [{'SiteTarget4-1': 3.28}],
#  'Target5': [{'SiteTarget5-1': -2.52}],
#  'Target6': [{'SiteTarget6-1': 2.72}],
#  'Target7': [{'SiteTarget7-1': 2.2}],
#  'Target8': [{'SiteTarget8-1': 1.1}],
#  'Target9': [{'SiteTarget9-1': -1.97}, {'SiteTarget9-2': 1.74}],
#  'Target10': [{'SiteTarget10-1': -0.93}],
#  'Target11': [{'SiteTarget11-1': -1.53}],
#  'Target12': [{'SiteTarget12-1': -1.53}],
#  'Target13': [{'SiteTarget13-1': 1.21}],
#  'Target14': [{'SiteTarget14-1': -2.68}],
#  'Target15': [{'SiteTarget15-1': 3.34}],
#  'Target16': [{'SiteTarget16-1': -3.26}],
#  'Target17': [{'SiteTarget17-1': -0.46},
#   {'SiteTarget17-2': 1.35},
#   {'SiteTarget17-3': -3.58},
#   {'SiteTarget17-4': -0.67},
#   {'SiteTarget17-5': -0.38},
#   {'SiteTarget17-6': 3.38}],
#  'Target18': [{'SiteTarget18-1': -2.09}, {'SiteTarget18-2': 2.28}],
#  'Target19': [{'SiteTarget19-1': -2.57}],
#  'Target20': [{'SiteTarget20-1': -3.82}],
#  'Target21': [{'SiteTarget21-1': -2.98},
#   {'SiteTarget21-2': 2.73},
#   {'SiteTarget21-3': -1.07},
#   {'SiteTarget21-4': 0.95}],
#  'Target22': [{'SiteTarget22-1': -1.21}],
#  'Target23': [{'SiteTarget23-1': -1.09}],
#  'Target24': [{'SiteTarget24-2': 3.89}, {'SiteTarget24-3': -1.75}],
#  'Target25': [{'SiteTarget25-1': -2.4}],
#  'Target26': [{'SiteTarget26-1': -3.34}]}

# %%
edge_att_1
# Out:
# {'Target1': 0.22206703910614523,
#  'Target2': 0.5111731843575419,
#  'Target3': 0.5391061452513967,
#  'Target4': 0.877094972067039,
#  'Target5': 0.5754189944134078,
#  'Target6': 0.11871508379888263,
#  'Target7': 0.03351955307262566,
#  'Target8': 0.803072625698324,
#  'Target9': 0.12430167597765358,
#  'Target10': 0.2108938547486033,
#  'Target11': 0.6606145251396647,
#  'Target12': 0.9441340782122905,
#  'Target13': 0.3072625698324022,
#  'Target14': 0.04050279329608939,
#  'Target15': 0.7807262569832402,
#  'Target16': 0.0,
#  'Target17': 0.8659217877094971,
#  'Target18': 0.7625698324022346,
#  'Target19': 0.4371508379888268,
#  'Target20': 0.20530726256983237,
#  'Target21': 0.8072625698324021,
#  'Target22': 0.8072625698324021,
#  'Target23': 1.0,
#  'Target24': 0.6648044692737429,
#  'Target25': 0.9790502793296089,
#  'Target26': 0.9790502793296089}

# %%
testing_a_null_column = partitions_dict(data, "TargetID", "hello", "TargetNodeColor")
testing_a_null_column
# Out:
# {}

# %%
dictionary = {"nodes": [], "links": []}

source = data["SourceID"].unique()
target = data["TargetID"].unique()

for s in source:
    dictionary['nodes'] += [{'id': s, "group": 1, "source_attr_1": source_att_1[s], "source_attr_2": source_att_1[s]}]
    
for t in target:
    dictionary['nodes'] += [{'id': t, "group": 2, "target_attr_2": target_att_2[t], "positions": partitions[t]}]
    
for s, t in links:
    dictionary['links'] += [{"source": s, "target": t, "edge_attr_1": edge_att_1[t], "edge_attr_2": edge_att_2[t]}]

# %%
with open('mockdata.json', 'w') as fp:
    json.dump(dictionary, fp)

# %%
dictionary
# Out:
# {'nodes': [{'id': 'Source1',
#    'group': 1,
#    'source_attr_1': 0.14634146341463417,
#    'source_attr_2': 0.14634146341463417},
#   {'id': 'Source2', 'group': 1, 'source_attr_1': 1.0, 'source_attr_2': 1.0},
#   {'id': 'Source3',
#    'group': 1,
#    'source_attr_1': 0.7392120075046904,
#    'source_attr_2': 0.7392120075046904},
#   {'id': 'Source4', 'group': 1, 'source_attr_1': 0.0, 'source_attr_2': 0.0},
#   {'id': 'Source5',
#    'group': 1,
#    'source_attr_1': 0.7450281425891182,
#    'source_attr_2': 0.7450281425891182},
#   {'id': 'Source6',
#    'group': 1,
#    'source_attr_1': 0.8405253283302064,
#    'source_attr_2': 0.8405253283302064},
#   {'id': 'Target1',
#    'group': 2,
#    'target_attr_2': 0.29639175257731953,
#    'positions': [{'SiteTarget1-1': -1.76},
#     {'SiteTarget1-2': 0.88},
#     {'SiteTarget1-3': 0.67},
#     {'SiteTarget1-4': -0.71}]},
#   {'id': 'Target2',
#    'group': 2,
#    'target_attr_2': 0.1958762886597938,
#    'positions': [{'SiteTarget2-1': -1.35}]},
#   {'id': 'Target3',
#    'group': 2,
#    'target_attr_2': 0.5927835051546392,
#    'positions': [{'SiteTarget3-1': 3.31},
#     {'SiteTarget3-2': -1.72},
#     {'SiteTarget3-3': -1.18},
#     {'SiteTarget3-4': -2.72}]},
#   {'id': 'Target4',
#    'group': 2,
#    'target_attr_2': 0.5438144329896908,
#    'positions': [{'SiteTarget4-1': 3.28}]},
#   {'id': 'Target5',
#    'group': 2,
#    'target_attr_2': 0.5489690721649485,
#    'positions': [{'SiteTarget5-1': -2.52}]},
#   {'id': 'Target6',
#    'group': 2,
#    'target_attr_2': 0.7989690721649484,
#    'positions': [{'SiteTarget6-1': 2.72}]},
#   {'id': 'Target7',
#    'group': 2,
#    'target_attr_2': 0.7628865979381444,
#    'positions': [{'SiteTarget7-1': 2.2}]},
#   {'id': 'Target8',
#    'group': 2,
#    'target_attr_2': 0.2628865979381443,
#    'positions': [{'SiteTarget8-1': 1.1}]},
#   {'id': 'Target9',
#    'group': 2,
#    'target_attr_2': 0.2989690721649484,
#    'positions': [{'SiteTarget9-1': -1.97}, {'SiteTarget9-2': 1.74}]},
#   {'id': 'Target10',
#    'group': 2,
#    'target_attr_2': 0.9201030927835051,
#    'positions': [{'SiteTarget10-1': -0.93}]},
#   {'id': 'Target11',
#    'group': 2,
#    'target_attr_2': 0.2628865979381443,
#    'positions': [{'SiteTarget11-1': -1.53}]},
#   {'id': 'Target12',
#    'group': 2,
#    'target_attr_2': 0.6984536082474228,
#    'positions': [{'SiteTarget12-1': -1.53}]},
#   {'id': 'Target13',
#    'group': 2,
#    'target_attr_2': 0.03350515463917526,
#    'positions': [{'SiteTarget13-1': 1.21}]},
#   {'id': 'Target14',
#    'group': 2,
#    'target_attr_2': 0.7938144329896907,
#    'positions': [{'SiteTarget14-1': -2.68}]},
#   {'id': 'Target15',
#    'group': 2,
#    'target_attr_2': 0.5721649484536082,
#    'positions': [{'SiteTarget15-1': 3.34}]},
#   {'id': 'Target16',
#    'group': 2,
#    'target_attr_2': 0.5850515463917525,
#    'positions': [{'SiteTarget16-1': -3.26}]},
#   {'id': 'Target17',
#    'group': 2,
#    'target_attr_2': 0.9510309278350516,
#    'positions': [{'SiteTarget17-1': -0.46},
#     {'SiteTarget17-2': 1.35},
#     {'SiteTarget17-3': -3.58},
#     {'SiteTarget17-4': -0.67},
#     {'SiteTarget17-5': -0.38},
#     {'SiteTarget17-6': 3.38}]},
#   {'id': 'Target18',
#    'group': 2,
#    'target_attr_2': 0.9123711340206185,
#    'positions': [{'SiteTarget18-1': -2.09}, {'SiteTarget18-2': 2.28}]},
#   {'id': 'Target19',
#    'group': 2,
#    'target_attr_2': 0.2036082474226804,
#    'positions': [{'SiteTarget19-1': -2.57}]},
#   {'id': 'Target20',
#    'group': 2,
#    'target_attr_2': 0.6881443298969072,
#    'positions': [{'SiteTarget20-1': -3.82}]},
#   {'id': 'Target21',
#    'group': 2,
#    'target_attr_2': 0.18556701030927833,
#    'positions': [{'SiteTarget21-1': -2.98},
#     {'SiteTarget21-2': 2.73},
#     {'SiteTarget21-3': -1.07},
#     {'SiteTarget21-4': 0.95}]},
#   {'id': 'Target22',
#    'group': 2,
#    'target_attr_2': 0.18556701030927833,
#    'positions': [{'SiteTarget22-1': -1.21}]},
#   {'id': 'Target23',
#    'group': 2,
#    'target_attr_2': 0.9407216494845361,
#    'positions': [{'SiteTarget23-1': -1.09}]},
#   {'id': 'Target24',
#    'group': 2,
#    'target_attr_2': 0.0,
#    'positions': [{'SiteTarget24-2': 3.89}, {'SiteTarget24-3': -1.75}]},
#   {'id': 'Target25',
#    'group': 2,
#    'target_attr_2': 0.4355670103092783,
#    'positions': [{'SiteTarget25-1': -2.4}]},
#   {'id': 'Target26',
#    'group': 2,
#    'target_attr_2': 0.4355670103092783,
#    'positions': [{'SiteTarget26-1': -3.34}]}],
#  'links': [{'source': 'Source1',
#    'target': 'Target1',
#    'edge_attr_1': 0.22206703910614523,
#    'edge_attr_2': 0.2689295039164491},
#   {'source': 'Source1',
#    'target': 'Target2',
#    'edge_attr_1': 0.5111731843575419,
#    'edge_attr_2': 0.15404699738903394},
#   {'source': 'Source1',
#    'target': 'Target3',
#    'edge_attr_1': 0.5391061452513967,
#    'edge_attr_2': 0.6501305483028721},
#   {'source': 'Source1',
#    'target': 'Target4',
#    'edge_attr_1': 0.877094972067039,
#    'edge_attr_2': 0.8172323759791124},
#   {'source': 'Source1',
#    'target': 'Target5',
#    'edge_attr_1': 0.5754189944134078,
#    'edge_attr_2': 0.7049608355091385},
#   {'source': 'Source1',
#    'target': 'Target6',
#    'edge_attr_1': 0.11871508379888263,
#    'edge_attr_2': 0.36814621409921666},
#   {'source': 'Source2',
#    'target': 'Target1',
#    'edge_attr_1': 0.22206703910614523,
#    'edge_attr_2': 0.2689295039164491},
#   {'source': 'Source2',
#    'target': 'Target7',
#    'edge_attr_1': 0.03351955307262566,
#    'edge_attr_2': 0.3472584856396867},
#   {'source': 'Source3',
#    'target': 'Target8',
#    'edge_attr_1': 0.803072625698324,
#    'edge_attr_2': 0.216710182767624},
#   {'source': 'Source3',
#    'target': 'Target3',
#    'edge_attr_1': 0.5391061452513967,
#    'edge_attr_2': 0.6501305483028721},
#   {'source': 'Source3',
#    'target': 'Target9',
#    'edge_attr_1': 0.12430167597765358,
#    'edge_attr_2': 0.8746736292428199},
#   {'source': 'Source3',
#    'target': 'Target10',
#    'edge_attr_1': 0.2108938547486033,
#    'edge_attr_2': 0.5613577023498695},
#   {'source': 'Source3',
#    'target': 'Target11',
#    'edge_attr_1': 0.6606145251396647,
#    'edge_attr_2': 0.32114882506527415},
#   {'source': 'Source3',
#    'target': 'Target12',
#    'edge_attr_1': 0.9441340782122905,
#    'edge_attr_2': 0.5378590078328982},
#   {'source': 'Source3',
#    'target': 'Target13',
#    'edge_attr_1': 0.3072625698324022,
#    'edge_attr_2': 0.9138381201044387},
#   {'source': 'Source3',
#    'target': 'Target14',
#    'edge_attr_1': 0.04050279329608939,
#    'edge_attr_2': 0.9712793733681463},
#   {'source': 'Source3',
#    'target': 'Target15',
#    'edge_attr_1': 0.7807262569832402,
#    'edge_attr_2': 0.6527415143603134},
#   {'source': 'Source3',
#    'target': 'Target16',
#    'edge_attr_1': 0.0,
#    'edge_attr_2': 0.5378590078328982},
#   {'source': 'Source4',
#    'target': 'Target17',
#    'edge_attr_1': 0.8659217877094971,
#    'edge_attr_2': 1.0},
#   {'source': 'Source4',
#    'target': 'Target18',
#    'edge_attr_1': 0.7625698324022346,
#    'edge_attr_2': 0.37597911227154046},
#   {'source': 'Source4',
#    'target': 'Target19',
#    'edge_attr_1': 0.4371508379888268,
#    'edge_attr_2': 0.0},
#   {'source': 'Source4',
#    'target': 'Target20',
#    'edge_attr_1': 0.20530726256983237,
#    'edge_attr_2': 0.5013054830287206},
#   {'source': 'Source5',
#    'target': 'Target21',
#    'edge_attr_1': 0.8072625698324021,
#    'edge_attr_2': 0.5430809399477807},
#   {'source': 'Source5',
#    'target': 'Target22',
#    'edge_attr_1': 0.8072625698324021,
#    'edge_attr_2': 0.5430809399477807},
#   {'source': 'Source5',
#    'target': 'Target23',
#    'edge_attr_1': 1.0,
#    'edge_attr_2': 0.8903394255874674},
#   {'source': 'Source5',
#    'target': 'Target17',
#    'edge_attr_1': 0.8659217877094971,
#    'edge_attr_2': 1.0},
#   {'source': 'Source5',
#    'target': 'Target5',
#    'edge_attr_1': 0.5754189944134078,
#    'edge_attr_2': 0.7049608355091385},
#   {'source': 'Source6',
#    'target': 'Target24',
#    'edge_attr_1': 0.6648044692737429,
#    'edge_attr_2': 0.5300261096605745},
#   {'source': 'Source6',
#    'target': 'Target25',
#    'edge_attr_1': 0.9790502793296089,
#    'edge_attr_2': 0.47780678851174935},
#   {'source': 'Source6',
#    'target': 'Target26',
#    'edge_attr_1': 0.9790502793296089,
#    'edge_attr_2': 0.47780678851174935},
#   {'source': 'Source6',
#    'target': 'Target23',
#    'edge_attr_1': 1.0,
#    'edge_attr_2': 0.8903394255874674}]}
