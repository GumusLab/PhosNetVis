# %%
import csv
import numpy as np
import pandas as pd
import json
from functools import reduce

# %%
# data = pd.read_csv("TestData/MockData2-goodNames-normalized.csv") 
# data = pd.read_csv("TestData/COVID.csv")
# data1 = pd.read_csv("TestData/1_ToyDataset-All.csv") 
# data2 = pd.read_csv("TestData/2_ToyDataset-NoEdges.csv") 
data1 = pd.read_csv("TestData/1_ToyDataset-All copy.csv") 
data2 = pd.read_csv("TestData/1_ToyDataset-All copy 2.csv")

# %%
num_data = 2

# %%
# GOAL
{
    "ids":
        ["PAK2", "HRI", "P20152", "Q01986", "P01237"],

    "nodes": 
        [{"id": "PAK2", "group": "1", "states":[{"source_attr_1": -1, "source_attr_2": 3}, 
                                                {"source_attr_1": -5, "source_attr_2": 5}]},
        {"id": "HRI", "group": "1", "states":[{"source_attr_1": 3, "source_attr_2": 1},
                                              {"source_attr_1": -4, "source_attr_2": 1}]},
        {"id": "P20152", "group": "2", "states": [{"target_attr_2": 0.01, "target_attr_1": [{"ph7" : 3.5}, {"ph206" : -5.2}, {"ph306": -7.5}]},
                                                  {"target_attr_2": 2, "target_attr_1": [{"ph7" : -3}, {"ph206" : 1}, {"ph306": 0.2}]}]},
        {"id": "Q01986", "group": "2", "states":[{"target_attr_2": -1, "target_attr_1": [{"ph7" : 2.1}, {"ph206" : -3.9}]},
                                                {"target_attr_2": 4, "target_attr_1": [{"ph7" : -4}]}]},
        {"id": "P01237", "group": "2", "states":[{"target_attr_2": 2, "target_attr_1": [{}]}]}],

    "links": 
        [{"source": "PAK2", "target": "P20152", "edge_attr": [{"dataset":0, "edge_attr_1": -1, "edge_attr_2": 3}, 
                                                              {"dataset":1, "edge_attr_1": -5, "edge_attr_2": 5}]}, 
        {"source": "PAK2", "target": "Q01986", "edge_attr":[{"dataset":0, "edge_attr_1": -1, "edge_attr_2": 3}, 
                                                              {"dataset":1, "edge_attr_1": -5, "edge_attr_2": 5}]},  
        {"source": "HRI", "target": "P01237", "edge_attr": [{"dataset":0, "edge_attr_1": -1, "edge_attr_2": 3}, 
                                                              {"dataset":1, "edge_attr_1": -5, "edge_attr_2": 5}]}]
        }
# Out:
#   File "<ipython-input-4-b556c3d3c4e1>", line 3
#     "ids":
#     ^
# IndentationError: unexpected indent

# %%
datasets = [data1, data2]

# %%
def normalize(values, actual_bounds, desired_bounds):
    final = []
    for i in values:
        final.append(desired_bounds[0] + (i - actual_bounds[0]) * (desired_bounds[1] - desired_bounds[0]) / (actual_bounds[1] - actual_bounds[0]))
    return final

# %%
def attribute_dict (dataframe, col_name_source_or_target, col_name_attribute_of_interest):
    dictionary = {}
    
    min_val = min(dataframe[col_name_attribute_of_interest].values)
    max_val = max(dataframe[col_name_attribute_of_interest].values)
    actual_bounds = (min_val, max_val)
    desired_bounds = (0, 1)
    
    for i in range(len(dataframe)):
        if col_name_attribute_of_interest in dataframe.columns:
            value = dataframe[col_name_attribute_of_interest][i]
            dictionary[dataframe[col_name_source_or_target][i]] = normalize([value], actual_bounds, desired_bounds)[0]
        else:
            dictionary[dataframe[col_name_source_or_target][i]] = None
            
    return dictionary

# %%
def partitions_dict (dataframe, col_name_target, col_name_partitions, col_name_attribute_of_interest):
    partitions = {}
    rep = {}

    target = dataframe[col_name_target]
    val = dataframe[col_name_attribute_of_interest]

    if col_name_partitions in dataframe.columns:
        site = dataframe[col_name_partitions]
        for i in range(len(dataframe)):
            if target[i] not in partitions:
                partitions[target[i]] = [{site[i]: val[i]}]
                rep[target[i]] = [site[i]]

            else:
                if site[i] not in rep[target[i]]:
                    partitions[target[i]] += [{site[i]: val[i]}]
                    rep[target[i]] += [site[i]]
    
    return partitions

# %%
def links_info (dataframe, col_name_source, col_name_target):
    links = []

    for i in range(len(dataframe)):
        if [dataframe[col_name_source][i], dataframe[col_name_target][i]] not in links:
            links.append([dataframe[col_name_source][i], dataframe[col_name_target][i]])
    return links

# %%
links
# Out:
# [['Source1', 'Target1'],
#  ['Source1', 'Target2'],
#  ['Source1', 'Target3'],
#  ['Source1', 'Target4'],
#  ['Source1', 'Target5'],
#  ['Source1', 'Target6'],
#  ['Source2', 'Target1'],
#  ['Source2', 'Target7'],
#  ['Source3', 'Target8'],
#  ['Source3', 'Target3'],
#  ['Source3', 'Target9'],
#  ['Source3', 'Target10'],
#  ['Source3', 'Target11'],
#  ['Source3', 'Target12'],
#  ['Source3', 'Target13'],
#  ['Source3', 'Target14'],
#  ['Source3', 'Target15'],
#  ['Source3', 'Target16'],
#  ['Source4', 'Target17'],
#  ['Source4', 'Target18'],
#  ['Source4', 'Target19'],
#  ['Source4', 'Target20'],
#  ['Source5', 'Target21'],
#  ['Source5', 'Target22'],
#  ['Source5', 'Target23'],
#  ['Source5', 'Target17'],
#  ['Source5', 'Target5'],
#  ['Source6', 'Target24'],
#  ['Source6', 'Target25'],
#  ['Source6', 'Target26'],
#  ['Source6', 'Target23']]

# %%
def sorce_states (datasets): #can be made for source and targets
    final = {}
    ks = []
    
    for j in datasets:
        ks += list(j["SourceID"])
    ks = set(ks)
    for i in range(len(datasets)):
        source_att_1 = attribute_dict(datasets[i], "SourceID", "SourceNodeColor")
        source_att_2 = attribute_dict(datasets[i], "SourceID", "SourceNodeSize")
        for k in ks:
            if k in list(datasets[i]["SourceID"]):
                if k in final:
                    final[k] += [{"dataset":i, "source_attr_1":source_att_1[k], "source_attr_2": source_att_2[k]}]
                else:
                    final[k] = [{"dataset":i, "source_attr_1":source_att_1[k], "source_attr_2": source_att_2[k]}]
            else:
                if k not in final:
                    final[k] = []

    return final

# %%
def target_states_NoPartitions (datasets):
    final = {}
    ks = []
    
    for j in datasets:
        ks += list(j["TargetID"])
    ks = set(ks)

    for i in range(len(datasets)):
        target_att_1 = attribute_dict(datasets[i], "TargetID", "TargetNodeColor")
        target_att_2 = attribute_dict(datasets[i], "TargetID", "TargetNodeSize")
        
        for k in ks:
            if k in list(datasets[i]["TargetID"]):
                if k in final:
                    final[k] += [{"dataset":i, "target_att_1":target_att_1[k], "target_att_2": target_att_2[k]}]
                else:
                    final[k] = [{"dataset":i, "target_att_1":target_att_1[k], "target_att_2": target_att_2[k]}]
            else:
                if k not in final:
                    final[k] = []

    return final

# %%
def target_states_Partitions (datasets):
    final = {}
    ks = []
    
    for j in datasets:
        ks += list(j["TargetID"])
    ks = set(ks)

    for i in range(len(datasets)):
        target_att_2 = attribute_dict(datasets[i], "TargetID", "TargetNodeSize")
        partitions = partitions_dict(datasets[i], "TargetID", "PhosphorylationSiteID", "TargetNodeColor")
        
        for k in ks:
            if k in list(datasets[i]["TargetID"]):
                if k in final:
                    final[k] += [{"dataset":i, "target_att_1":partitions[k], "target_att_2": target_att_2[k]}]
                else:
                    final[k] = [{"dataset":i, "target_att_1":partitions[k], "target_att_2": target_att_2[k]}]
            else:
                if k not in final:
                    final[k] = []

    return final

# %%
source_att = sorce_states(datasets) #STATE #ID
target_states_NoPartitions_d = target_states_NoPartitions(datasets) #STATE #ID
target_states_Partitions_d = target_states_Partitions(datasets) #STATE #ID

# %%
source_att
# Out:
# {'Source4': [{'dataset': 0,
#    'source_attr_1': 0.0,
#    'source_attr_2': 0.2555066079295154},
#   {'dataset': 1, 'source_attr_1': 0.0, 'source_attr_2': 0.2555066079295154}],
#  'Source6': [{'dataset': 0,
#    'source_attr_1': 0.8405253283302064,
#    'source_attr_2': 0.3920704845814977},
#   {'dataset': 1,
#    'source_attr_1': 0.8405253283302064,
#    'source_attr_2': 0.3920704845814977}],
#  'Source3': [{'dataset': 0,
#    'source_attr_1': 0.7392120075046904,
#    'source_attr_2': 0.13656387665198239}],
#  'Source5': [{'dataset': 0,
#    'source_attr_1': 0.7450281425891182,
#    'source_attr_2': 1.0},
#   {'dataset': 1, 'source_attr_1': 0.7450281425891182, 'source_attr_2': 1.0}],
#  'Source1': [{'dataset': 0,
#    'source_attr_1': 0.14634146341463417,
#    'source_attr_2': 0.0},
#   {'dataset': 1, 'source_attr_1': 0.14634146341463417, 'source_attr_2': 0.0}],
#  'Source2': [{'dataset': 0,
#    'source_attr_1': 1.0,
#    'source_attr_2': 0.5044052863436124},
#   {'dataset': 1, 'source_attr_1': 1.0, 'source_attr_2': 0.5044052863436124}]}

# %%
target_states_Partitions_d["Target17"]
# Out:
# [{'dataset': 0,
#   'target_att_1': [{'SiteTarget17-1': -0.46},
#    {'SiteTarget17-2': 1.35},
#    {'SiteTarget17-3': -3.58},
#    {'SiteTarget17-4': -0.67},
#    {'SiteTarget17-5': -0.38},
#    {'SiteTarget17-6': 3.38}],
#   'target_att_2': 0.9510309278350516},
#  {'dataset': 1,
#   'target_att_1': [{'SiteTarget17-1': -0.46},
#    {'SiteTarget17-2': 1.35},
#    {'SiteTarget17-3': -3.58},
#    {'SiteTarget17-4': -0.67},
#    {'SiteTarget17-5': -0.38},
#    {'SiteTarget17-6': 3.38}],
#   'target_att_2': 0.9510309278350516}]

# %%
target_states_Partitions
# Out:
# <function __main__.target_states_Partitions(datasets)>

# %%
# source_att_1 = attribute_dict(data1, "SourceID", "SourceNodeColor")
# source_att_2 = attribute_dict(data1, "SourceID", "SourceNodeSize")
# target_att_1 = attribute_dict(data1, "TargetID", "TargetNodeColor")
# target_att_2 = attribute_dict(data1, "TargetID", "TargetNodeSize")
edge_att_1 = attribute_dict(data1, "TargetID", "EdgeColor")
edge_att_2 = attribute_dict(data1, "TargetID", "EdgeWeight")

# partitions = partitions_dict(data1, "TargetID", "PhosphorylationSiteID", "TargetNodeColor")
links = links_info(data1, "SourceID", "TargetID")

# %%
def edge_states (datasets): #can be made for source and targets
    final = {}
    ks = []
    
    for j in datasets:
        ks += list(j["TargetID"])
    ks = set(ks)
    for i in range(len(datasets)):
        edge_att_1 = attribute_dict(datasets[i], "TargetID", "EdgeColor")
        edge_att_2 = attribute_dict(datasets[i], "TargetID", "EdgeWeight")
        for k in ks:
            if k in list(datasets[i]["TargetID"]):
                if k in final:
                    final[k] += [{"dataset":i, "edge_att_1":edge_att_1[k], "edge_att_2": edge_att_2[k]}]
                else:
                    final[k] = [{"dataset":i, "edge_att_1":edge_att_1[k], "edge_att_2": edge_att_2[k]}]
            else:
                if k not in final:
                    final[k] = []

    return final

# %%
edge_states (datasets)
# Out:
# {'Target6': [{'dataset': 0,
#    'edge_att_1': 0.11871508379888263,
#    'edge_att_2': 0.36814621409921666},
#   {'dataset': 1,
#    'edge_att_1': 0.08815028901734102,
#    'edge_att_2': 0.36814621409921666}],
#  'Target12': [{'dataset': 0,
#    'edge_att_1': 0.9441340782122905,
#    'edge_att_2': 0.5378590078328982}],
#  'Target2': [{'dataset': 0,
#    'edge_att_1': 0.5111731843575419,
#    'edge_att_2': 0.15404699738903394},
#   {'dataset': 1,
#    'edge_att_1': 0.49421965317919075,
#    'edge_att_2': 0.15404699738903394}],
#  'Target17': [{'dataset': 0,
#    'edge_att_1': 0.8659217877094971,
#    'edge_att_2': 1.0},
#   {'dataset': 1, 'edge_att_1': 0.861271676300578, 'edge_att_2': 1.0}],
#  'Target7': [{'dataset': 0,
#    'edge_att_1': 0.03351955307262566,
#    'edge_att_2': 0.3472584856396867},
#   {'dataset': 1, 'edge_att_1': 0.0, 'edge_att_2': 0.3472584856396867}],
#  'Target8': [{'dataset': 0,
#    'edge_att_1': 0.803072625698324,
#    'edge_att_2': 0.216710182767624}],
#  'Target19': [{'dataset': 0,
#    'edge_att_1': 0.4371508379888268,
#    'edge_att_2': 0.0},
#   {'dataset': 1, 'edge_att_1': 0.41763005780346824, 'edge_att_2': 0.0}],
#  'Target10': [{'dataset': 0,
#    'edge_att_1': 0.2108938547486033,
#    'edge_att_2': 0.5613577023498695}],
#  'Target11': [{'dataset': 0,
#    'edge_att_1': 0.6606145251396647,
#    'edge_att_2': 0.32114882506527415}],
#  'Target24': [{'dataset': 0,
#    'edge_att_1': 0.6648044692737429,
#    'edge_att_2': 0.5300261096605745},
#   {'dataset': 1,
#    'edge_att_1': 0.653179190751445,
#    'edge_att_2': 0.5300261096605745}],
#  'Target13': [{'dataset': 0,
#    'edge_att_1': 0.3072625698324022,
#    'edge_att_2': 0.9138381201044387}],
#  'Target15': [{'dataset': 0,
#    'edge_att_1': 0.7807262569832402,
#    'edge_att_2': 0.6527415143603134}],
#  'Target26': [{'dataset': 0,
#    'edge_att_1': 0.9790502793296089,
#    'edge_att_2': 0.47780678851174935},
#   {'dataset': 1,
#    'edge_att_1': 0.9783236994219653,
#    'edge_att_2': 0.47780678851174935}],
#  'Target5': [{'dataset': 0,
#    'edge_att_1': 0.5754189944134078,
#    'edge_att_2': 0.7049608355091385},
#   {'dataset': 1,
#    'edge_att_1': 0.5606936416184971,
#    'edge_att_2': 0.7049608355091385}],
#  'Target20': [{'dataset': 0,
#    'edge_att_1': 0.20530726256983237,
#    'edge_att_2': 0.5013054830287206},
#   {'dataset': 1,
#    'edge_att_1': 0.1777456647398844,
#    'edge_att_2': 0.5013054830287206}],
#  'Target23': [{'dataset': 0,
#    'edge_att_1': 1.0,
#    'edge_att_2': 0.8903394255874674},
#   {'dataset': 1, 'edge_att_1': 1.0, 'edge_att_2': 0.8903394255874674}],
#  'Target9': [{'dataset': 0,
#    'edge_att_1': 0.12430167597765358,
#    'edge_att_2': 0.8746736292428199}],
#  'Target22': [{'dataset': 0,
#    'edge_att_1': 0.8072625698324021,
#    'edge_att_2': 0.5430809399477807},
#   {'dataset': 1,
#    'edge_att_1': 0.8005780346820809,
#    'edge_att_2': 0.5430809399477807}],
#  'Target14': [{'dataset': 0,
#    'edge_att_1': 0.04050279329608939,
#    'edge_att_2': 0.9712793733681463}],
#  'Target4': [{'dataset': 0,
#    'edge_att_1': 0.877094972067039,
#    'edge_att_2': 0.8172323759791124},
#   {'dataset': 1,
#    'edge_att_1': 0.8728323699421966,
#    'edge_att_2': 0.8172323759791124}],
#  'Target16': [{'dataset': 0,
#    'edge_att_1': 0.0,
#    'edge_att_2': 0.5378590078328982}],
#  'Target1': [{'dataset': 0,
#    'edge_att_1': 0.22206703910614523,
#    'edge_att_2': 0.2689295039164491},
#   {'dataset': 1,
#    'edge_att_1': 0.19508670520231217,
#    'edge_att_2': 0.2689295039164491}],
#  'Target21': [{'dataset': 0,
#    'edge_att_1': 0.8072625698324021,
#    'edge_att_2': 0.5430809399477807},
#   {'dataset': 1,
#    'edge_att_1': 0.8005780346820809,
#    'edge_att_2': 0.5430809399477807}],
#  'Target25': [{'dataset': 0,
#    'edge_att_1': 0.9790502793296089,
#    'edge_att_2': 0.47780678851174935},
#   {'dataset': 1,
#    'edge_att_1': 0.9783236994219653,
#    'edge_att_2': 0.47780678851174935}],
#  'Target18': [{'dataset': 0,
#    'edge_att_1': 0.7625698324022346,
#    'edge_att_2': 0.37597911227154046},
#   {'dataset': 1,
#    'edge_att_1': 0.7543352601156069,
#    'edge_att_2': 0.37597911227154046}],
#  'Target3': [{'dataset': 0,
#    'edge_att_1': 0.5391061452513967,
#    'edge_att_2': 0.6501305483028721},
#   {'dataset': 1,
#    'edge_att_1': 0.9401734104046243,
#    'edge_att_2': 0.1409921671018277}]}

# %%
# testing_a_null_column = partitions_dict(data, "TargetID", "hello", "TargetNodeColor")
# testing_a_null_column

# %%
# dictionary = {"nodes": [], "links": []}

# source = data["SourceID"].unique()
# target = data["TargetID"].unique()

# for s in source:
#     dictionary['nodes'] += [{'id': s, "group": 1, "source_attr_1": source_att_1[s], "source_attr_2": source_att_1[s]}]
    
# for t in target:
#     dictionary['nodes'] += [{'id': t, "group": 2, "target_attr_2": target_att_2[t], "positions": partitions[t]}]
    
# for s, t in links:
#     dictionary['links'] += [{"source": s, "target": t, "edge_attr_1": edge_att_1[t], "edge_attr_2": edge_att_2[t]}]

# %%
dictionary = {"nodes": [], "links": []}

# source = data["SourceID"].unique()
# target = data["TargetID"].unique()

source = []    
for j in datasets:
    source += list(j["SourceID"])
source = set(source)

target = []    
for j in datasets:
    target += list(j["TargetID"])
target = set(target)


for s in source:
    dictionary['nodes'] += [{'id': s, "group": 1, "states": source_att[s]}]
    
for t in target:
    dictionary['nodes'] += [{'id': t, "group": 2, "state": target_states_Partitions_d[t]}]
    
for s, t in links:
    dictionary['links'] += [{"source": s, "target": t, "edge_attr_1": edge_att_1[t], "edge_attr_2": edge_att_2[t]}]

# %%
with open('mockdata.json', 'w') as fp:
    json.dump(dictionary, fp)

# %%
dictionary
# Out:
# {'nodes': [{'id': 'Source4',
#    'group': 1,
#    'states': [{'dataset': 0,
#      'source_attr_1': 0.0,
#      'source_attr_2': 0.2555066079295154},
#     {'dataset': 1,
#      'source_attr_1': 0.0,
#      'source_attr_2': 0.2555066079295154}]},
#   {'id': 'Source6',
#    'group': 1,
#    'states': [{'dataset': 0,
#      'source_attr_1': 0.8405253283302064,
#      'source_attr_2': 0.3920704845814977},
#     {'dataset': 1,
#      'source_attr_1': 0.8405253283302064,
#      'source_attr_2': 0.3920704845814977}]},
#   {'id': 'Source3',
#    'group': 1,
#    'states': [{'dataset': 0,
#      'source_attr_1': 0.7392120075046904,
#      'source_attr_2': 0.13656387665198239}]},
#   {'id': 'Source5',
#    'group': 1,
#    'states': [{'dataset': 0,
#      'source_attr_1': 0.7450281425891182,
#      'source_attr_2': 1.0},
#     {'dataset': 1,
#      'source_attr_1': 0.7450281425891182,
#      'source_attr_2': 1.0}]},
#   {'id': 'Source1',
#    'group': 1,
#    'states': [{'dataset': 0,
#      'source_attr_1': 0.14634146341463417,
#      'source_attr_2': 0.0},
#     {'dataset': 1,
#      'source_attr_1': 0.14634146341463417,
#      'source_attr_2': 0.0}]},
#   {'id': 'Source2',
#    'group': 1,
#    'states': [{'dataset': 0,
#      'source_attr_1': 1.0,
#      'source_attr_2': 0.5044052863436124},
#     {'dataset': 1,
#      'source_attr_1': 1.0,
#      'source_attr_2': 0.5044052863436124}]},
#   {'id': 'Target6',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget6-1': 2.72}],
#      'target_att_2': 0.7989690721649484},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget6-1': 2.72}],
#      'target_att_2': 0.7989690721649484}]},
#   {'id': 'Target12',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget12-1': -1.53}],
#      'target_att_2': 0.6984536082474228}]},
#   {'id': 'Target2',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget2-1': -1.35}],
#      'target_att_2': 0.1958762886597938},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget2-1': -1.35}],
#      'target_att_2': 0.1958762886597938}]},
#   {'id': 'Target17',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget17-1': -0.46},
#       {'SiteTarget17-2': 1.35},
#       {'SiteTarget17-3': -3.58},
#       {'SiteTarget17-4': -0.67},
#       {'SiteTarget17-5': -0.38},
#       {'SiteTarget17-6': 3.38}],
#      'target_att_2': 0.9510309278350516},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget17-1': -0.46},
#       {'SiteTarget17-2': 1.35},
#       {'SiteTarget17-3': -3.58},
#       {'SiteTarget17-4': -0.67},
#       {'SiteTarget17-5': -0.38},
#       {'SiteTarget17-6': 3.38}],
#      'target_att_2': 0.9510309278350516}]},
#   {'id': 'Target7',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget7-1': 2.2}],
#      'target_att_2': 0.7628865979381444},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget7-1': 2.2}],
#      'target_att_2': 0.7628865979381444}]},
#   {'id': 'Target8',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget8-1': 1.1}],
#      'target_att_2': 0.2628865979381443}]},
#   {'id': 'Target19',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget19-1': -2.57}],
#      'target_att_2': 0.2036082474226804},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget19-1': -2.57}],
#      'target_att_2': 0.2036082474226804}]},
#   {'id': 'Target10',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget10-1': -0.93}],
#      'target_att_2': 0.9201030927835051}]},
#   {'id': 'Target11',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget11-1': -1.53}],
#      'target_att_2': 0.2628865979381443}]},
#   {'id': 'Target24',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget24-2': 3.89}, {'SiteTarget24-3': -1.75}],
#      'target_att_2': 0.0},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget24-2': 3.89}, {'SiteTarget24-3': -1.75}],
#      'target_att_2': 0.0}]},
#   {'id': 'Target13',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget13-1': 1.21}],
#      'target_att_2': 0.03350515463917526}]},
#   {'id': 'Target15',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget15-1': 3.34}],
#      'target_att_2': 0.5721649484536082}]},
#   {'id': 'Target26',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget26-1': -3.34}],
#      'target_att_2': 0.4355670103092783},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget26-1': -3.34}],
#      'target_att_2': 0.4355670103092783}]},
#   {'id': 'Target5',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget5-1': -2.52}],
#      'target_att_2': 0.5489690721649485},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget5-1': -2.52}],
#      'target_att_2': 0.5489690721649485}]},
#   {'id': 'Target20',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget20-1': -3.82}],
#      'target_att_2': 0.6881443298969072},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget20-1': -3.82}],
#      'target_att_2': 0.6881443298969072}]},
#   {'id': 'Target23',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget23-1': -1.09}],
#      'target_att_2': 0.9407216494845361},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget23-1': -1.09}],
#      'target_att_2': 0.9407216494845361}]},
#   {'id': 'Target9',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget9-1': -1.97}, {'SiteTarget9-2': 1.74}],
#      'target_att_2': 0.2989690721649484}]},
#   {'id': 'Target22',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget22-1': -1.21}],
#      'target_att_2': 0.18556701030927833},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget22-1': -1.21}],
#      'target_att_2': 0.18556701030927833}]},
#   {'id': 'Target14',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget14-1': -2.68}],
#      'target_att_2': 0.7938144329896907}]},
#   {'id': 'Target4',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget4-1': 3.28}],
#      'target_att_2': 0.5438144329896908},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget4-1': 3.28}],
#      'target_att_2': 0.5438144329896908}]},
#   {'id': 'Target16',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget16-1': -3.26}],
#      'target_att_2': 0.5850515463917525}]},
#   {'id': 'Target1',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget1-1': -1.76},
#       {'SiteTarget1-2': 0.88},
#       {'SiteTarget1-3': 0.67},
#       {'SiteTarget1-4': -0.71}],
#      'target_att_2': 0.29639175257731953},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget1-1': -1.76},
#       {'SiteTarget1-2': 0.88},
#       {'SiteTarget1-3': 0.67},
#       {'SiteTarget1-4': -0.71}],
#      'target_att_2': 0.29639175257731953}]},
#   {'id': 'Target21',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget21-1': -2.98},
#       {'SiteTarget21-2': 2.73},
#       {'SiteTarget21-3': -1.07},
#       {'SiteTarget21-4': 0.95}],
#      'target_att_2': 0.18556701030927833},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget21-1': -2.98},
#       {'SiteTarget21-2': 2.73},
#       {'SiteTarget21-3': -1.07},
#       {'SiteTarget21-4': 0.95}],
#      'target_att_2': 0.18556701030927833}]},
#   {'id': 'Target25',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget25-1': -2.4}],
#      'target_att_2': 0.4355670103092783},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget25-1': -2.4}],
#      'target_att_2': 0.4355670103092783}]},
#   {'id': 'Target18',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget18-1': -2.09}, {'SiteTarget18-2': 2.28}],
#      'target_att_2': 0.9123711340206185},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget18-1': -2.09}, {'SiteTarget18-2': 2.28}],
#      'target_att_2': 0.9123711340206185}]},
#   {'id': 'Target3',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget3-1': 3.31},
#       {'SiteTarget3-2': -1.72},
#       {'SiteTarget3-3': -1.18},
#       {'SiteTarget3-4': -2.72}],
#      'target_att_2': 0.5927835051546392},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget3-1': 3.31},
#       {'SiteTarget3-2': -1.72},
#       {'SiteTarget3-3': -1.18},
#       {'SiteTarget3-4': -2.72}],
#      'target_att_2': 0.5927835051546392}]}],
#  'links': [{'source': 'Source1',
#    'target': 'Target1',
#    'edge_attr_1': 0.22206703910614523,
#    'edge_attr_2': 0.2689295039164491},
#   {'source': 'Source1',
#    'target': 'Target2',
#    'edge_attr_1': 0.5111731843575419,
#    'edge_attr_2': 0.15404699738903394},
#   {'source': 'Source1',
#    'target': 'Target3',
#    'edge_attr_1': 0.5391061452513967,
#    'edge_attr_2': 0.6501305483028721},
#   {'source': 'Source1',
#    'target': 'Target4',
#    'edge_attr_1': 0.877094972067039,
#    'edge_attr_2': 0.8172323759791124},
#   {'source': 'Source1',
#    'target': 'Target5',
#    'edge_attr_1': 0.5754189944134078,
#    'edge_attr_2': 0.7049608355091385},
#   {'source': 'Source1',
#    'target': 'Target6',
#    'edge_attr_1': 0.11871508379888263,
#    'edge_attr_2': 0.36814621409921666},
#   {'source': 'Source2',
#    'target': 'Target1',
#    'edge_attr_1': 0.22206703910614523,
#    'edge_attr_2': 0.2689295039164491},
#   {'source': 'Source2',
#    'target': 'Target7',
#    'edge_attr_1': 0.03351955307262566,
#    'edge_attr_2': 0.3472584856396867},
#   {'source': 'Source3',
#    'target': 'Target8',
#    'edge_attr_1': 0.803072625698324,
#    'edge_attr_2': 0.216710182767624},
#   {'source': 'Source3',
#    'target': 'Target3',
#    'edge_attr_1': 0.5391061452513967,
#    'edge_attr_2': 0.6501305483028721},
#   {'source': 'Source3',
#    'target': 'Target9',
#    'edge_attr_1': 0.12430167597765358,
#    'edge_attr_2': 0.8746736292428199},
#   {'source': 'Source3',
#    'target': 'Target10',
#    'edge_attr_1': 0.2108938547486033,
#    'edge_attr_2': 0.5613577023498695},
#   {'source': 'Source3',
#    'target': 'Target11',
#    'edge_attr_1': 0.6606145251396647,
#    'edge_attr_2': 0.32114882506527415},
#   {'source': 'Source3',
#    'target': 'Target12',
#    'edge_attr_1': 0.9441340782122905,
#    'edge_attr_2': 0.5378590078328982},
#   {'source': 'Source3',
#    'target': 'Target13',
#    'edge_attr_1': 0.3072625698324022,
#    'edge_attr_2': 0.9138381201044387},
#   {'source': 'Source3',
#    'target': 'Target14',
#    'edge_attr_1': 0.04050279329608939,
#    'edge_attr_2': 0.9712793733681463},
#   {'source': 'Source3',
#    'target': 'Target15',
#    'edge_attr_1': 0.7807262569832402,
#    'edge_attr_2': 0.6527415143603134},
#   {'source': 'Source3',
#    'target': 'Target16',
#    'edge_attr_1': 0.0,
#    'edge_attr_2': 0.5378590078328982},
#   {'source': 'Source4',
#    'target': 'Target17',
#    'edge_attr_1': 0.8659217877094971,
#    'edge_attr_2': 1.0},
#   {'source': 'Source4',
#    'target': 'Target18',
#    'edge_attr_1': 0.7625698324022346,
#    'edge_attr_2': 0.37597911227154046},
#   {'source': 'Source4',
#    'target': 'Target19',
#    'edge_attr_1': 0.4371508379888268,
#    'edge_attr_2': 0.0},
#   {'source': 'Source4',
#    'target': 'Target20',
#    'edge_attr_1': 0.20530726256983237,
#    'edge_attr_2': 0.5013054830287206},
#   {'source': 'Source5',
#    'target': 'Target21',
#    'edge_attr_1': 0.8072625698324021,
#    'edge_attr_2': 0.5430809399477807},
#   {'source': 'Source5',
#    'target': 'Target22',
#    'edge_attr_1': 0.8072625698324021,
#    'edge_attr_2': 0.5430809399477807},
#   {'source': 'Source5',
#    'target': 'Target23',
#    'edge_attr_1': 1.0,
#    'edge_attr_2': 0.8903394255874674},
#   {'source': 'Source5',
#    'target': 'Target17',
#    'edge_attr_1': 0.8659217877094971,
#    'edge_attr_2': 1.0},
#   {'source': 'Source5',
#    'target': 'Target5',
#    'edge_attr_1': 0.5754189944134078,
#    'edge_attr_2': 0.7049608355091385},
#   {'source': 'Source6',
#    'target': 'Target24',
#    'edge_attr_1': 0.6648044692737429,
#    'edge_attr_2': 0.5300261096605745},
#   {'source': 'Source6',
#    'target': 'Target25',
#    'edge_attr_1': 0.9790502793296089,
#    'edge_attr_2': 0.47780678851174935},
#   {'source': 'Source6',
#    'target': 'Target26',
#    'edge_attr_1': 0.9790502793296089,
#    'edge_attr_2': 0.47780678851174935},
#   {'source': 'Source6',
#    'target': 'Target23',
#    'edge_attr_1': 1.0,
#    'edge_attr_2': 0.8903394255874674}]}

# %%
dictionary
# Out:
# {'nodes': [{'id': 'Source2',
#    'group': 1,
#    'states': [{'dataset': 0,
#      'source_attr_1': 1.0,
#      'source_attr_2': 0.5044052863436124},
#     {'dataset': 1,
#      'source_attr_1': 1.0,
#      'source_attr_2': 0.5044052863436124}]},
#   {'id': 'Source1',
#    'group': 1,
#    'states': [{'dataset': 0,
#      'source_attr_1': 0.14634146341463417,
#      'source_attr_2': 0.0},
#     {'dataset': 1,
#      'source_attr_1': 0.14634146341463417,
#      'source_attr_2': 0.0}]},
#   {'id': 'Source6',
#    'group': 1,
#    'states': [{'dataset': 0,
#      'source_attr_1': 0.8405253283302064,
#      'source_attr_2': 0.3920704845814977},
#     {'dataset': 1,
#      'source_attr_1': 0.8405253283302064,
#      'source_attr_2': 0.3920704845814977}]},
#   {'id': 'Source3',
#    'group': 1,
#    'states': [{'dataset': 0,
#      'source_attr_1': 0.7392120075046904,
#      'source_attr_2': 0.13656387665198239}]},
#   {'id': 'Source5',
#    'group': 1,
#    'states': [{'dataset': 0,
#      'source_attr_1': 0.7450281425891182,
#      'source_attr_2': 1.0},
#     {'dataset': 1,
#      'source_attr_1': 0.7450281425891182,
#      'source_attr_2': 1.0}]},
#   {'id': 'Source4',
#    'group': 1,
#    'states': [{'dataset': 0,
#      'source_attr_1': 0.0,
#      'source_attr_2': 0.2555066079295154},
#     {'dataset': 1,
#      'source_attr_1': 0.0,
#      'source_attr_2': 0.2555066079295154}]},
#   {'id': 'Target24',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget24-2': 3.89}, {'SiteTarget24-3': -1.75}],
#      'target_att_2': 0.0},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget24-2': 3.89}, {'SiteTarget24-3': -1.75}],
#      'target_att_2': 0.0}]},
#   {'id': 'Target15',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget15-1': 3.34}],
#      'target_att_2': 0.5721649484536082}]},
#   {'id': 'Target13',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget13-1': 1.21}],
#      'target_att_2': 0.03350515463917526}]},
#   {'id': 'Target14',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget14-1': -2.68}],
#      'target_att_2': 0.7938144329896907}]},
#   {'id': 'Target12',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget12-1': -1.53}],
#      'target_att_2': 0.6984536082474228}]},
#   {'id': 'Target16',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget16-1': -3.26}],
#      'target_att_2': 0.5850515463917525}]},
#   {'id': 'Target4',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget4-1': 3.28}],
#      'target_att_2': 0.5438144329896908},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget4-1': 3.28}],
#      'target_att_2': 0.5438144329896908}]},
#   {'id': 'Target9',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget9-1': -1.97}, {'SiteTarget9-2': 1.74}],
#      'target_att_2': 0.2989690721649484}]},
#   {'id': 'Target21',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget21-1': -2.98},
#       {'SiteTarget21-2': 2.73},
#       {'SiteTarget21-3': -1.07},
#       {'SiteTarget21-4': 0.95}],
#      'target_att_2': 0.18556701030927833},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget21-1': -2.98},
#       {'SiteTarget21-2': 2.73},
#       {'SiteTarget21-3': -1.07},
#       {'SiteTarget21-4': 0.95}],
#      'target_att_2': 0.18556701030927833}]},
#   {'id': 'Target19',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget19-1': -2.57}],
#      'target_att_2': 0.2036082474226804},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget19-1': -2.57}],
#      'target_att_2': 0.2036082474226804}]},
#   {'id': 'Target10',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget10-1': -0.93}],
#      'target_att_2': 0.9201030927835051}]},
#   {'id': 'Target5',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget5-1': -2.52}],
#      'target_att_2': 0.5489690721649485},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget5-1': -2.52}],
#      'target_att_2': 0.5489690721649485}]},
#   {'id': 'Target17',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget17-1': -0.46},
#       {'SiteTarget17-2': 1.35},
#       {'SiteTarget17-3': -3.58},
#       {'SiteTarget17-4': -0.67},
#       {'SiteTarget17-5': -0.38},
#       {'SiteTarget17-6': 3.38}],
#      'target_att_2': 0.9510309278350516},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget17-1': -0.46},
#       {'SiteTarget17-2': 1.35},
#       {'SiteTarget17-3': -3.58},
#       {'SiteTarget17-4': -0.67},
#       {'SiteTarget17-5': -0.38},
#       {'SiteTarget17-6': 3.38}],
#      'target_att_2': 0.9510309278350516}]},
#   {'id': 'Target22',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget22-1': -1.21}],
#      'target_att_2': 0.18556701030927833},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget22-1': -1.21}],
#      'target_att_2': 0.18556701030927833}]},
#   {'id': 'Target6',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget6-1': 2.72}],
#      'target_att_2': 0.7989690721649484},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget6-1': 2.72}],
#      'target_att_2': 0.7989690721649484}]},
#   {'id': 'Target26',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget26-1': -3.34}],
#      'target_att_2': 0.4355670103092783},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget26-1': -3.34}],
#      'target_att_2': 0.4355670103092783}]},
#   {'id': 'Target25',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget25-1': -2.4}],
#      'target_att_2': 0.4355670103092783},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget25-1': -2.4}],
#      'target_att_2': 0.4355670103092783}]},
#   {'id': 'Target2',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget2-1': -1.35}],
#      'target_att_2': 0.1958762886597938},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget2-1': -1.35}],
#      'target_att_2': 0.1958762886597938}]},
#   {'id': 'Target7',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget7-1': 2.2}],
#      'target_att_2': 0.7628865979381444},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget7-1': 2.2}],
#      'target_att_2': 0.7628865979381444}]},
#   {'id': 'Target23',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget23-1': -1.09}],
#      'target_att_2': 0.9407216494845361},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget23-1': -1.09}],
#      'target_att_2': 0.9407216494845361}]},
#   {'id': 'Target20',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget20-1': -3.82}],
#      'target_att_2': 0.6881443298969072},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget20-1': -3.82}],
#      'target_att_2': 0.6881443298969072}]},
#   {'id': 'Target3',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget3-1': 3.31},
#       {'SiteTarget3-2': -1.72},
#       {'SiteTarget3-3': -1.18},
#       {'SiteTarget3-4': -2.72}],
#      'target_att_2': 0.5927835051546392},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget3-1': 3.31},
#       {'SiteTarget3-2': -1.72},
#       {'SiteTarget3-3': -1.18},
#       {'SiteTarget3-4': -2.72}],
#      'target_att_2': 0.5927835051546392}]},
#   {'id': 'Target1',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget1-1': -1.76},
#       {'SiteTarget1-2': 0.88},
#       {'SiteTarget1-3': 0.67},
#       {'SiteTarget1-4': -0.71}],
#      'target_att_2': 0.29639175257731953},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget1-1': -1.76},
#       {'SiteTarget1-2': 0.88},
#       {'SiteTarget1-3': 0.67},
#       {'SiteTarget1-4': -0.71}],
#      'target_att_2': 0.29639175257731953}]},
#   {'id': 'Target11',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget11-1': -1.53}],
#      'target_att_2': 0.2628865979381443}]},
#   {'id': 'Target8',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget8-1': 1.1}],
#      'target_att_2': 0.2628865979381443}]},
#   {'id': 'Target18',
#    'group': 2,
#    'state': [{'dataset': 0,
#      'target_att_1': [{'SiteTarget18-1': -2.09}, {'SiteTarget18-2': 2.28}],
#      'target_att_2': 0.9123711340206185},
#     {'dataset': 1,
#      'target_att_1': [{'SiteTarget18-1': -2.09}, {'SiteTarget18-2': 2.28}],
#      'target_att_2': 0.9123711340206185}]}],
#  'links': [{'source': 'Source1',
#    'target': 'Target1',
#    'edge_attr_1': 0.22206703910614523,
#    'edge_attr_2': 0.2689295039164491},
#   {'source': 'Source1',
#    'target': 'Target2',
#    'edge_attr_1': 0.5111731843575419,
#    'edge_attr_2': 0.15404699738903394},
#   {'source': 'Source1',
#    'target': 'Target3',
#    'edge_attr_1': 0.5391061452513967,
#    'edge_attr_2': 0.6501305483028721},
#   {'source': 'Source1',
#    'target': 'Target4',
#    'edge_attr_1': 0.877094972067039,
#    'edge_attr_2': 0.8172323759791124},
#   {'source': 'Source1',
#    'target': 'Target5',
#    'edge_attr_1': 0.5754189944134078,
#    'edge_attr_2': 0.7049608355091385},
#   {'source': 'Source1',
#    'target': 'Target6',
#    'edge_attr_1': 0.11871508379888263,
#    'edge_attr_2': 0.36814621409921666},
#   {'source': 'Source2',
#    'target': 'Target1',
#    'edge_attr_1': 0.22206703910614523,
#    'edge_attr_2': 0.2689295039164491},
#   {'source': 'Source2',
#    'target': 'Target7',
#    'edge_attr_1': 0.03351955307262566,
#    'edge_attr_2': 0.3472584856396867},
#   {'source': 'Source3',
#    'target': 'Target8',
#    'edge_attr_1': 0.803072625698324,
#    'edge_attr_2': 0.216710182767624},
#   {'source': 'Source3',
#    'target': 'Target3',
#    'edge_attr_1': 0.5391061452513967,
#    'edge_attr_2': 0.6501305483028721},
#   {'source': 'Source3',
#    'target': 'Target9',
#    'edge_attr_1': 0.12430167597765358,
#    'edge_attr_2': 0.8746736292428199},
#   {'source': 'Source3',
#    'target': 'Target10',
#    'edge_attr_1': 0.2108938547486033,
#    'edge_attr_2': 0.5613577023498695},
#   {'source': 'Source3',
#    'target': 'Target11',
#    'edge_attr_1': 0.6606145251396647,
#    'edge_attr_2': 0.32114882506527415},
#   {'source': 'Source3',
#    'target': 'Target12',
#    'edge_attr_1': 0.9441340782122905,
#    'edge_attr_2': 0.5378590078328982},
#   {'source': 'Source3',
#    'target': 'Target13',
#    'edge_attr_1': 0.3072625698324022,
#    'edge_attr_2': 0.9138381201044387},
#   {'source': 'Source3',
#    'target': 'Target14',
#    'edge_attr_1': 0.04050279329608939,
#    'edge_attr_2': 0.9712793733681463},
#   {'source': 'Source3',
#    'target': 'Target15',
#    'edge_attr_1': 0.7807262569832402,
#    'edge_attr_2': 0.6527415143603134},
#   {'source': 'Source3',
#    'target': 'Target16',
#    'edge_attr_1': 0.0,
#    'edge_attr_2': 0.5378590078328982},
#   {'source': 'Source4',
#    'target': 'Target17',
#    'edge_attr_1': 0.8659217877094971,
#    'edge_attr_2': 1.0},
#   {'source': 'Source4',
#    'target': 'Target18',
#    'edge_attr_1': 0.7625698324022346,
#    'edge_attr_2': 0.37597911227154046},
#   {'source': 'Source4',
#    'target': 'Target19',
#    'edge_attr_1': 0.4371508379888268,
#    'edge_attr_2': 0.0},
#   {'source': 'Source4',
#    'target': 'Target20',
#    'edge_attr_1': 0.20530726256983237,
#    'edge_attr_2': 0.5013054830287206},
#   {'source': 'Source5',
#    'target': 'Target21',
#    'edge_attr_1': 0.8072625698324021,
#    'edge_attr_2': 0.5430809399477807},
#   {'source': 'Source5',
#    'target': 'Target22',
#    'edge_attr_1': 0.8072625698324021,
#    'edge_attr_2': 0.5430809399477807},
#   {'source': 'Source5',
#    'target': 'Target23',
#    'edge_attr_1': 1.0,
#    'edge_attr_2': 0.8903394255874674},
#   {'source': 'Source5',
#    'target': 'Target17',
#    'edge_attr_1': 0.8659217877094971,
#    'edge_attr_2': 1.0},
#   {'source': 'Source5',
#    'target': 'Target5',
#    'edge_attr_1': 0.5754189944134078,
#    'edge_attr_2': 0.7049608355091385},
#   {'source': 'Source6',
#    'target': 'Target24',
#    'edge_attr_1': 0.6648044692737429,
#    'edge_attr_2': 0.5300261096605745},
#   {'source': 'Source6',
#    'target': 'Target25',
#    'edge_attr_1': 0.9790502793296089,
#    'edge_attr_2': 0.47780678851174935},
#   {'source': 'Source6',
#    'target': 'Target26',
#    'edge_attr_1': 0.9790502793296089,
#    'edge_attr_2': 0.47780678851174935},
#   {'source': 'Source6',
#    'target': 'Target23',
#    'edge_attr_1': 1.0,
#    'edge_attr_2': 0.8903394255874674}]}
